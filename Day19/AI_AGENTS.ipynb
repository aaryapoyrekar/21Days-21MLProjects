# %% [markdown]
# # The Future of Coding?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Philosophical Question: What is the difference between a coder and a developer?

# %% [markdown]
# # What are Agents?
#
# What is compute =  It is a generic term used to reference processing power, memory, networking, storage, and other resources required for the computational success of any program.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# What is Agentic AI, then?
#
# # Why Crew AI?
#
# It had the first mover advantage.
#
# Other Agentic AI Framework to follow in 2025:
# - [AutoGen](https://www.microsoft.com/en-us/research/project/autogen/)
# - [Pydantic AI](https://ai.pydantic.dev/)
#
# # Crew AI in 5 minutes
#
# *Source: crewai.com*
#
# ## Step 1: Create Your Crew
# Define custom Agents with flexible Roles and Goals – whether for data research, automation, or content generation, crewAI puts you in control.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Step 2: Define Tasks
# Assign tasks to your agents, clearly defining what they need to accomplish. Ensure seamless collaboration by setting clear instructions and expected outcomes.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Step 3: Kickoff
# Launch your crew into action with a single command. Monitor progress in real-time and receive the results directly, ready for review.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # The Crew Framework
#
# ## Understanding the "Crew" AI Framework
#
# The Crew framework is an organized, interactive model designed for collaborative work among AI agents.
#
# ### 1. Crew
# - **What is it?**
#   - A structured system encompassing agents, processes, tasks, and outcomes.
#   - Think of it as the environment or ecosystem in which all other parts operate.
#
# ### 2. AI Agents
# - **Role:**
#   - "Intelligent" entities capable of collaboration and decision-making.
#   - They can delegate tasks, ask questions, and interact dynamically.
# - **Interaction:**
#   - Agents communicate with each other to manage workload effectively.
#   - They utilize tools to enhance their performance.
#
# ### 3. Tools
# - **Purpose:**
#   - External resources or utilities used by AI agents.
#   - Provide support for completing tasks efficiently and effectively.
#
# ### 4. Process
# - **Function:**
#   - Defines and organizes how agents collaborate and assign tasks.
#   - Manages how agents interact and execute their work.
# - **Interactions:**
#   - Receives input or guidance from agents.
#   - Provides feedback loops back to agents for continuous improvement.
#   - Ensures tasks are systematically allocated.
#
# ### 5. Tasks
# - **Definition:**
#   - Specific units of work to be executed within the Crew framework.
#   - Clearly defined steps or jobs created and distributed by the process.
# - **Characteristics:**
#   - Can specify or override particular tools required for completion.
#   - May assign certain tasks explicitly to specific AI agents.
#
#
#
# ### Workflow Summary:
# - **Step-by-step:**
#   1. **AI Agents** collaborate, communicate, and delegate tasks among themselves.
#   2. **Process** organizes these interactions, determining how tasks are managed.
#   3. **Tasks** are assigned clearly, possibly with specific tools or agents required.
#   4. **Tasks** are completed by agents using available **Tools**.
#   5. **Outcomes** are produced, demonstrating successful execution and fulfillment of objectives.

# %% [markdown]
# # The Mental Framework for AI Agents
#
#
# | Component | Mental Framework                     | Key Features                                              |
# |-----------|---------------------------------|-----------------------------------------------------------|
# | Crew      | The top-level organization/department      | - Manages AI agent teams<br>- Oversees workflows<br>- Ensures collaboration<br>- Delivers outcomes |
# | AI Agents | Specialized team members        | - Have specific roles <br>- Use designated tools<br>- Can delegate tasks<br>- Make autonomous decisions |
# | Process   | Workflow management system      | - Defines collaboration patterns<br>- Controls task assignments<br>- Manages interactions<br>- Ensures efficient execution |
# | Tasks     | Individual assignments          | - Have clear objectives<br>- Use specific tools<br>- Feed into larger process<br>- Produce actionable results |

# %% [markdown]
# - Data Science Product Research Department (Crew)
#   - Market Researcher (Agent)
#   - Data Analyst (Agent)
#   - Data Scientist (Agent)
#   - Manager (Orchestrating Agent)
#
#
#   - Tasks
#     - Finding new improvements in existing systems/processes available in the market
#     - Collecting data
#         - Internet Search Capability (Tools)
#         - Web Scraping Capability (Tools)
#         - Storage organization Capability (Tools)
#
#     - Analyzing data
#     - RnD on new tech
#     - Creating reports
#     - Publishing reports & data

# %% [markdown]
# # Let's Experiment!
#
#
#
# ## 🚀 **Experiment 1: Content Creation Workflow**
#
# ### 🛠️ **Initial Setup and Environment Configuration**
#
# ```python
# # Suppress warnings for clean output
# import warnings
# warnings.filterwarnings('ignore')
#
# # Import necessary modules from CrewAI
# from crewai import Agent, Task, Crew
#
# # Set OpenAI model to GPT-3.5 Turbo
# import os
# os.environ["OPENAI_MODEL_NAME"] = 'gpt-3.5-turbo'
# ```
#
# ### 🤖 **Define Agents**
#
# ```python
# # Content Planner Agent
# planner = Agent(
#     role="Content Planner",
#     goal="Plan engaging and factually accurate content on {topic}",
#     backstory=(
#         "You're planning a blog article on the topic: {topic}. "
#         "You collect informative content to educate the audience and enable informed decisions."
#     ),
#     allow_delegation=False,
#     verbose=True
# )
#
# # Content Writer Agent
# writer = Agent(
#     role="Content Writer",
#     goal="Write an insightful, factually accurate opinion piece about {topic}",
#     backstory=(
#         "You're writing an opinion piece based on the planner's outline. "
#         "You clearly differentiate objective statements from opinions."
#     ),
#     allow_delegation=False,
#     verbose=True
# )
#
# # Editor Agent
# editor = Agent(
#     role="Editor",
#     goal="Edit blog posts aligning with the organization's style",
#     backstory=(
#         "You review blog posts ensuring journalistic best practices, balanced viewpoints, and avoidance of controversial issues."
#     ),
#     allow_delegation=False,
#     verbose=True
# )
# ```
#
# ### ✅ **Define Tasks**
#
# ```python
# # Task for planning content
# plan = Task(
#     description=(
#         "1. Highlight latest trends, key players, and notable news on {topic}.\n"
#         "2. Identify target audience interests and challenges.\n"
#         "3. Create detailed content outline (intro, main points, CTA).\n"
#         "4. Include SEO keywords and relevant resources."
#     ),
#     expected_output="Detailed content plan including outline, audience analysis, SEO keywords, and resources.",
#     agent=planner,
# )
#
# # Task for writing content
# write = Task(
#     description=(
#         "1. Write compelling blog post using content plan.\n"
#         "2. Integrate SEO keywords naturally.\n"
#         "3. Create engaging and descriptive sections/subtitles.\n"
#         "4. Structure clearly (introduction, body, conclusion).\n"
#         "5. Proofread for grammar and brand voice consistency."
#     ),
#     expected_output="Markdown formatted, publication-ready blog post with structured paragraphs.",
#     agent=writer,
# )
#
# # Task for editing content
# edit = Task(
#     description="Proofread the blog post for grammar, clarity, and alignment with brand voice.",
#     expected_output="Finalized markdown blog post, ready for publication.",
#     agent=editor
# )
# ```
#
# ### ⚙️ **Execute Crew Workflow**
#
# ```python
# # Create and kickoff crew
# crew = Crew(agents=[planner, writer, editor], tasks=[plan, write, edit], verbose=True)
#
# # Run the content creation process
# result = crew.kickoff(inputs={"topic": "Artificial Intelligence"})
# ```

# %% [markdown]
# ## 🎧 **Experiment 2: Customer Support Workflow**
#
# ### 📦 **Initial Setup and Environment Configuration**
#
# ```python
# # Import tools for web scraping and searching
# from crewai_tools import ScrapeWebsiteTool
#
# # Suppress warnings
# import warnings
# warnings.filterwarnings('ignore')
#
# # Configure OpenAI model
# import os
# os.environ["OPENAI_MODEL_NAME"] = 'gpt-4o-mini'
# ```
#
# ### 🤖 **Define Customer Support Agents**
#
# ```python
# # Senior Support Representative Agent
# support_agent = Agent(
#     role="Senior Support Representative",
#     goal="Provide friendly, comprehensive customer support",
#     backstory=(
#         "You provide exceptional support for critical customers like {customer}."
#         "Answer thoroughly without assumptions."
#     ),
#     allow_delegation=False,
#     verbose=True
# )
#
# # Support Quality Assurance Agent
# support_quality_assurance_agent = Agent(
#     role="Support Quality Assurance Specialist",
#     goal="Ensure top-quality customer support interactions",
#     backstory=(
#         "You ensure responses meet high standards, completeness, and friendliness for customers like {customer}."
#     ),
#     verbose=True
# )
# ```
#
# ### 📝 **Define Support Tasks**
#
# ```python
# # Web scraping tool for documentation
#  docs_scrape_tool = ScrapeWebsiteTool(website_url="https://docs.crewai.com/how-to/Creating-a-Crew-and-kick-it-off/")
#
# # Task for resolving customer inquiries
# inquiry_resolution = Task(
#     description=(
#         "{customer} has an urgent inquiry:\n{inquiry}\n"
#         "Use comprehensive resources to deliver accurate and helpful responses."
#     ),
#     expected_output=(
#         "Detailed, informative, and friendly response addressing the customer's complete inquiry, citing all resources."
#     ),
#     tools=[docs_scrape_tool],
#     agent=support_agent,
# )
#
# # Task for quality assurance
# quality_assurance_review = Task(
#     description=(
#         "Review the drafted response ensuring accuracy, completeness, and friendly tone. Confirm resource citation."
#     ),
#     expected_output=(
#         "Final, comprehensive, customer-ready response with professional yet relaxed tone."
#     ),
#     agent=support_quality_assurance_agent,
# )
# ```
#
# ### 🚦 **Execute Customer Support Crew Workflow**
#
# ```python
# # Create and run customer support crew
# crew = Crew(
#   agents=[support_agent, support_quality_assurance_agent],
#   tasks=[inquiry_resolution, quality_assurance_review],
#   verbose=2,
#   memory=True
# )
#
# # Customer inquiry inputs
# inputs = {
#     "customer": "GeeksForGeeks",
#     "person": "Sampurn Rattan",
#     "inquiry": (
#         "I need help setting up and kicking off a Crew, particularly adding memory functionality."
#     )
# }
#
# # Execute the customer support process
# result = crew.kickoff(inputs=inputs)
# ```

# %% [markdown]
# # Let's Code our Market Analyst
#
# ## Installations

# %%
# !pip install crewai crewai-tools langchain-google-genai

# %% [markdown]
# ## Basic Imports

# %%
import os
from crewai import Agent, Task, Crew, Process, LLM
from crewai_tools import SerperDevTool
from google.colab import userdata

# %% [markdown]
# ## Initialize the Gemini model

# %%
gemini_llm = LLM(
    model="gemini/gemini-2.5-flash",
    api_key=userdata.get('GPPGLE')
)

# %% [markdown]
# ## Initialize the search tool
#
# https://serper.dev/api-keys

# %%
# Load the API key from Colab secrets
serper_api_key = userdata.get('SERPER_API_KEY')

# Set it as an environment variable
os.environ["SERPER_API_KEY"] = serper_api_key

search_tool = SerperDevTool()

# %% [markdown]
# ## Create a researcher agent

# %%
researcher = Agent(
  role='Market Researcher',
  goal='Find and analyze the latest trends in the AI industry',
  backstory="""You are an expert market researcher. You are skilled at
  finding the most relevant and up-to-date information on any given
  topic, and you are known for your ability to synthesize complex
  information into clear and concise summaries.""",
  verbose=True,
  allow_delegation=False,
  tools=[search_tool],
  llm=gemini_llm
)

# %% [markdown]
# ##Create a writer agent

# %%
writer = Agent(
  role='Content Writer',
  goal='Write a compelling and engaging blog post about the latest AI trends',
  backstory="""You are a renowned content writer, known for your ability
  to create engaging and informative content. You have a knack for
  turning complex topics into easy-to-understand articles that
  resonate with a wide audience.""",
  verbose=True,
  allow_delegation=True,
  llm=gemini_llm
)

# %% [markdown]
# ##Create the research task

# %%
research_task = Task(
  description="""Research the latest trends in the AI industry.
  Your research should focus on the most significant advancements,
  emerging technologies, and key players. The final output should be a
  detailed report with your findings.""",
  expected_output='A comprehensive report summarizing the latest AI trends.',
  agent=researcher
)

# %% [markdown]
# ##Create the writing task

# %%
write_task = Task(
  description="""Write a blog post based on the research findings.
  The blog post should be engaging, informative, and accessible to a
  non-technical audience. It should highlight the key trends and their
  potential impact on the future.""",
  expected_output='A 500-word blog post on the latest AI trends.',
  agent=writer
)

# %% [markdown]
# ##Create the crew

# %%
marketing_crew = Crew(
  agents=[researcher, writer],
  tasks=[research_task, write_task],
  process=Process.sequential,
  verbose=True
)

# %% [markdown]
# # Kick off the crew

# %%
result = marketing_crew.kickoff()
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: adaacde1-808e-4055-8765-d1533e3c1274                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ...

# %%
# Define the filename
output_filename = "blog_post.md"

# Open the file in write mode ('w') and save the content
with open(output_filename, 'w', encoding='utf-8') as file:
    file.write(result.raw)

print(f"\n Blog post successfully saved to {output_filename}")
# Out:
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: adaacde1-808e-4055-8765-d1533e3c1274                                                                       │
# │  Tool Args:                                                                                                     │
# │  Final Output: ## AI Unlocked: Navigating the Brave New World of Artificial Intelligence                        │
# │                                                                                                                 │
# ...

# %% [markdown]
# # Can you summarize the output in 30-40 lines?

# %% [markdown]
# This project made me understand Agentic AI and how multiple AI agents can work together like a team. Instead of writing code that runs step by step, I explored how AI systems can think, plan, and collaborate .The main goal of this project was to build an Autonomous Market Analyst using the CrewAI framework. A coder focuses on writing instructions, while a developer focuses on building systems that solve real problems.
#
# I started by understanding what agents are and how compute powers everything behind the scenes. Then I explored the idea of Agentic AI, where agents are not just tools but decision makers. CrewAI is one of the first frameworks to make agent collaboration practical and easy. I also learned about other upcoming framework like Pydantic AI.
#
# The core idea of CrewAI is the “Crew” which works like a department in a company. Each agent has a clear role, goal, and responsibility. Some agents focus on research, some on writing, and others on quality checks.Tasks are defined so agents know exactly what they need to do. Processes control how agents communicate and pass work to each other.
#
# I built a market analyst system using Gemini and live web search tools.
# One agent researched the latest AI trends while another turned the research into a blog post. The entire workflow ran sequentially without manual intervention.
# This project showed me how powerful AI agents can be when designed correctly.
# More importantly, it changed how I think about building intelligent systems.
# This was not just coding for me it was learning how to design thinking machines.
